# %% [markdown]
# #Ejercicio de ingreso

# %% [markdown]
# ##Agenda
# 1. Insercion de bloques de texto
# 2. Insercion de titulos
# 3. trabajando con el bloque de codigo

# %% [markdown]
# se aprende a usar el coamndo print y el uso de comentarios

# %%
# este es un comentario
print("Hola extraterrestres")
# Out:
# Hola extraterrestres
